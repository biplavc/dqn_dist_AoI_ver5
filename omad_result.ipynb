# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from networkx import *
import random
from scipy.spatial.distance import pdist, squareform
from networkx.algorithms.approximation import min_weighted_dominating_set
from itertools import product  
# from age_calculation import *

# from networkx.algorithms.approximation import dominating_set
from parameters import *
# from create_graph_1 import *
from itertools import combinations
from itertools import permutations
import pickle
import itertools
# %matplotlib inline

# %%
# dqn_3U_final = dqn_3U_final[3]
MAD_mean_3 = 7.26
omad_mean_3 = 7.18
rr_mean_3 = 9
greedy_mean_3 = 7.56
random_mean_3 = 10.24
pf_mean_3 = 10
dqn_mean_3 = 7

import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['MAD', 'oMAD']
students = [MAD_mean_3, oMAD_mean_3]
ax.bar(langs,students, color=['crimson', 'gold'])


# legend.get_frame().set_facecolor('0.90')
# ax1.set_title('8 users with 5 UAVs and $e$=0', fontsize='x-large')
plt.show
plt.xticks(fontsize='20')
plt.yticks(fontsize='20')
plt.xlabel('Schedulers', fontsize='20')
plt.ylabel('AoI($T$) in ms', fontsize='20')
# plt.ticklabel_format(axis='both', style='sci')
# pyplot.ion
plt.show()

print(f"students = {students}")

# %%
# dqn_3U_final = dqn_3U_final[3]
MAD_mean_3 = 7.26
omad_mean_3 = 7.18
rr_mean_3 = 9
MAF_mean_3 = 7.56
random_mean_3 = 10.24
pf_mean_3 = 10
dqn_mean_3 = 7

import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['DQN', 'oMAD', 'MAD', 'MAF', 'RR', 'PF', 'Random']
students = [dqn_mean_3, omad_mean_3, MAD_mean_3, MAF_mean_3, rr_mean_3, pf_mean_3, random_mean_3]
ax.bar(langs,students)


# legend.get_frame().set_facecolor('0.90')
# ax1.set_title('8 users with 5 UAVs and $e$=0', fontsize='x-large')
plt.show
plt.xticks(fontsize='20')
plt.yticks(fontsize='20')
plt.xlabel('Schedulers', fontsize='20')
plt.ylabel('AoI($T$) in ms', fontsize='20')
# plt.ticklabel_format(axis='both', style='sci')
# pyplot.ion
plt.show()

print(f"students = {students}")
